# %% [markdown]
# <a href="https://colab.research.google.com/github/introvert-balak/Electric-Vehicle-Market-Segmentation-Analysis/blob/main/Ev_market_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv('/content/EV data.csv')
df.head()
# Out:
#          Brand                          Model  Accel_sec  TopSpeed_km_per_h  \
# 0       Tesla   Model 3 Long Range Dual Motor        4.6                233
# 1  Volkswagen                       ID.3 Pure       10.0                160
# 2    Polestar                               2        4.7                210
# 3         BMW                            iX3         6.8                180
# 4       Honda                              e         9.5                145
#
#    Range_km  Efficiency_wh_per_km FastCharge_km_per_h  \
# 0       450                   161                 940
# 1       270                   167                 250
# 2       400                   181                 620
# 3       360                   206                 560
# 4       170                   168                 190
#
#                RapidCharge        PowerTrain    PlugType  BodyStyle Segment  \
# 0  Rapid charging possible   All Wheel Drive  Type 2 CCS      Sedan       D
# 1  Rapid charging possible  Rear Wheel Drive  Type 2 CCS  Hatchback       C
# 2  Rapid charging possible   All Wheel Drive  Type 2 CCS   Liftback       D
# 3  Rapid charging possible  Rear Wheel Drive  Type 2 CCS        SUV       D
# 4  Rapid charging possible  Rear Wheel Drive  Type 2 CCS  Hatchback       B
#
#    Seats  PriceEuro
# 0      5      55480
# 1      5      30000
# 2      5      56440
# 3      5      68040
# 4      4      32997
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6919164303393431982 = autoviz.get_registered_df('df_6919164303393431982')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6919164303393431982, *['Accel_sec'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2417599005129108346 = autoviz.get_registered_df('df_2417599005129108346')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2417599005129108346, *['TopSpeed_km_per_h'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4751657432179230323 = autoviz.get_registered_df('df_4751657432179230323')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4751657432179230323, *['Range_km'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7427015869355875665 = autoviz.get_registered_df('df_7427015869355875665')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7427015869355875665, *['Efficiency_wh_per_km'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1906547760934510934 = autoviz.get_registered_df('df_1906547760934510934')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_1906547760934510934, *['Accel_sec'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2480416008642116772 = autoviz.get_registered_df('df_2480416008642116772')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2480416008642116772, *['TopSpeed_km_per_h'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4715790697329782120 = autoviz.get_registered_df('df_4715790697329782120')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_4715790697329782120, *['Range_km'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3208780001182982155 = autoviz.get_registered_df('df_3208780001182982155')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3208780001182982155, *['Efficiency_wh_per_km'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5100877749139616897 = autoviz.get_registered_df('df_5100877749139616897')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_5100877749139616897, *['Brand'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7750381626975121415 = autoviz.get_registered_df('df_7750381626975121415')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_7750381626975121415, *['Model'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2423050340593332536 = autoviz.get_registered_df('df_2423050340593332536')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_2423050340593332536, *['FastCharge_km_per_h'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7851846419943130987 = autoviz.get_registered_df('df_7851846419943130987')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_7851846419943130987, *['PowerTrain'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3394678448336985188 = autoviz.get_registered_df('df_3394678448336985188')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_3394678448336985188, *[[['Accel_sec', 'TopSpeed_km_per_h'], ['TopSpeed_km_per_h', 'Range_km'], ['Range_km', 'Efficiency_wh_per_km'], ['Efficiency_wh_per_km', 'Seats']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1576990412109182252 = autoviz.get_registered_df('df_1576990412109182252')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_1576990412109182252, *['Brand', 'Model'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2330462974549695728 = autoviz.get_registered_df('df_2330462974549695728')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_2330462974549695728, *['Model', 'FastCharge_km_per_h'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8209518875410493988 = autoviz.get_registered_df('df_8209518875410493988')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_8209518875410493988, *['FastCharge_km_per_h', 'PowerTrain'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4520662834886224599 = autoviz.get_registered_df('df_4520662834886224599')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_4520662834886224599, *['PowerTrain', 'BodyStyle'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_797803923745925231 = autoviz.get_registered_df('df_797803923745925231')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_797803923745925231, *['Accel_sec', 'Brand'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_110687220077942931 = autoviz.get_registered_df('df_110687220077942931')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_110687220077942931, *['Accel_sec', 'Model'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1307787637622950324 = autoviz.get_registered_df('df_1307787637622950324')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1307787637622950324, *['Accel_sec', 'FastCharge_km_per_h'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3288330012094219577 = autoviz.get_registered_df('df_3288330012094219577')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_3288330012094219577, *['Accel_sec', 'PowerTrain'], **{'inner': 'stick'})
# chart

# %%
df.shape
# Out:
# (103, 14)

# %%
df.dtypes
# Out:
# Brand                    object
# Model                    object
# Accel_sec               float64
# TopSpeed_km_per_h         int64
# Range_km                  int64
# Efficiency_wh_per_km      int64
# FastCharge_km_per_h      object
# RapidCharge              object
# PowerTrain               object
# PlugType                 object
# BodyStyle                object
# Segment                  object
# Seats                     int64
# PriceEuro                 int64
# dtype: object

# %%
df.describe()
# Out:
#         Accel_sec  TopSpeed_km_per_h    Range_km  Efficiency_wh_per_km  \
# count  103.000000         103.000000  103.000000            103.000000
# mean     7.396117         179.194175  338.786408            189.165049
# std      3.017430          43.573030  126.014444             29.566839
# min      2.100000         123.000000   95.000000            104.000000
# 25%      5.100000         150.000000  250.000000            168.000000
# 50%      7.300000         160.000000  340.000000            180.000000
# 75%      9.000000         200.000000  400.000000            203.000000
# max     22.400000         410.000000  970.000000            273.000000
#
#             Seats      PriceEuro
# count  103.000000     103.000000
# mean     4.883495   55811.563107
# std      0.795834   34134.665280
# min      2.000000   20129.000000
# 25%      5.000000   34429.500000
# 50%      5.000000   45000.000000
# 75%      5.000000   65000.000000
# max      7.000000  215000.000000

# %%
df1 = df[df.FastCharge_km_per_h !='-']
df1.shape
# Out:
# (98, 14)

# %%
df1.FastCharge_km_per_h=pd.to_numeric(df1.FastCharge_km_per_h)
df1.dtypes
# Out:
# Brand                    object
# Model                    object
# Accel_sec               float64
# TopSpeed_km_per_h         int64
# Range_km                  int64
# Efficiency_wh_per_km      int64
# FastCharge_km_per_h       int64
# RapidCharge              object
# PowerTrain               object
# PlugType                 object
# BodyStyle                object
# Segment                  object
# Seats                     int64
# PriceEuro                 int64
# dtype: object

# %%
df2 = df1
df2.head()
# Out:
#          Brand                          Model  Accel_sec  TopSpeed_km_per_h  \
# 0       Tesla   Model 3 Long Range Dual Motor        4.6                233
# 1  Volkswagen                       ID.3 Pure       10.0                160
# 2    Polestar                               2        4.7                210
# 3         BMW                            iX3         6.8                180
# 4       Honda                              e         9.5                145
#
#    Range_km  Efficiency_wh_per_km  FastCharge_km_per_h  \
# 0       450                   161                  940
# 1       270                   167                  250
# 2       400                   181                  620
# 3       360                   206                  560
# 4       170                   168                  190
#
#                RapidCharge        PowerTrain    PlugType  BodyStyle Segment  \
# 0  Rapid charging possible   All Wheel Drive  Type 2 CCS      Sedan       D
# 1  Rapid charging possible  Rear Wheel Drive  Type 2 CCS  Hatchback       C
# 2  Rapid charging possible   All Wheel Drive  Type 2 CCS   Liftback       D
# 3  Rapid charging possible  Rear Wheel Drive  Type 2 CCS        SUV       D
# 4  Rapid charging possible  Rear Wheel Drive  Type 2 CCS  Hatchback       B
#
#    Seats  PriceEuro
# 0      5      55480
# 1      5      30000
# 2      5      56440
# 3      5      68040
# 4      4      32997
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3587611774950878694 = autoviz.get_registered_df('df_3587611774950878694')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3587611774950878694, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8502563789013754616 = autoviz.get_registered_df('df_8502563789013754616')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8502563789013754616, *['Accel_sec'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_9120660048434693486 = autoviz.get_registered_df('df_9120660048434693486')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_9120660048434693486, *['TopSpeed_km_per_h'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7459039311301016075 = autoviz.get_registered_df('df_7459039311301016075')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7459039311301016075, *['Range_km'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7274004067180036422 = autoviz.get_registered_df('df_7274004067180036422')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_7274004067180036422, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3804644824949391125 = autoviz.get_registered_df('df_3804644824949391125')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3804644824949391125, *['Accel_sec'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2898038998781796352 = autoviz.get_registered_df('df_2898038998781796352')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2898038998781796352, *['TopSpeed_km_per_h'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7025316809711953297 = autoviz.get_registered_df('df_7025316809711953297')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_7025316809711953297, *['Range_km'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7821234380099805658 = autoviz.get_registered_df('df_7821234380099805658')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_7821234380099805658, *['Brand'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1064367075457546152 = autoviz.get_registered_df('df_1064367075457546152')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_1064367075457546152, *['Model'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1387737076283300292 = autoviz.get_registered_df('df_1387737076283300292')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_1387737076283300292, *['PowerTrain'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2971723061246873668 = autoviz.get_registered_df('df_2971723061246873668')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_2971723061246873668, *['BodyStyle'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8658615292772474821 = autoviz.get_registered_df('df_8658615292772474821')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_8658615292772474821, *[[['index', 'Accel_sec'], ['Accel_sec', 'TopSpeed_km_per_h'], ['TopSpeed_km_per_h', 'Range_km'], ['Range_km', 'Efficiency_wh_per_km']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3406697928526200560 = autoviz.get_registered_df('df_3406697928526200560')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_3406697928526200560, *['Brand', 'Model'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8486672177689234259 = autoviz.get_registered_df('df_8486672177689234259')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_8486672177689234259, *['Model', 'PowerTrain'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6363010614049703080 = autoviz.get_registered_df('df_6363010614049703080')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_6363010614049703080, *['PowerTrain', 'BodyStyle'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7683034212162721345 = autoviz.get_registered_df('df_7683034212162721345')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_7683034212162721345, *['BodyStyle', 'Segment'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5009666919203077194 = autoviz.get_registered_df('df_5009666919203077194')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_5009666919203077194, *['index', 'Brand'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1554080835664515399 = autoviz.get_registered_df('df_1554080835664515399')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1554080835664515399, *['index', 'Model'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2780103143822151055 = autoviz.get_registered_df('df_2780103143822151055')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_2780103143822151055, *['index', 'PowerTrain'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1407884859189208314 = autoviz.get_registered_df('df_1407884859189208314')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1407884859189208314, *['index', 'BodyStyle'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4739014504978842963 = autoviz.get_registered_df('df_4739014504978842963')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_4739014504978842963, *['index', 'Accel_sec', 'Brand'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_773156996746596399 = autoviz.get_registered_df('df_773156996746596399')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_773156996746596399, *['index', 'Accel_sec', 'Model'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7317232720745482500 = autoviz.get_registered_df('df_7317232720745482500')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7317232720745482500, *['index', 'Accel_sec', 'PowerTrain'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2761812223998658431 = autoviz.get_registered_df('df_2761812223998658431')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2761812223998658431, *['index', 'Accel_sec', 'BodyStyle'], **{})
# chart
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
import matplotlib.pyplot as plt

car_counts = df2['BodyStyle'].value_counts()

# Creating a pie chart
plt.figure(figsize=(10, 8))  # Adjusting the size of the figure

# Customizing colors for each pie slice
colors = ['#FF9999', '#66B2FF', '#99FF99', '#FFCC99', '#C2C2F0', '#FF99CC']

# Creating the pie chart with custom colors, labels, percentage format, and starting angle
plt.pie(car_counts, labels=car_counts.index, autopct='%.1f%%', startangle=90, colors=colors)

plt.title('Number of Cars by BodyStyle')
plt.axis('equal')  # Ensuring the pie chart is circular
plt.show()

# %%
import matplotlib.pyplot as plt

# Creating the histogram
plt.figure(figsize=(10, 8))  # Adjusting the size of the figure

# Customizing the color of the histogram bars
color = 'skyblue'

# Creating the histogram with the custom color
plt.hist(df2['TopSpeed_km_per_h'], bins=10, color=color)

plt.title('Distribution of Top Speed')
plt.xlabel('Top Speed (km/h)')
plt.ylabel('Frequency')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_20_fastest = df.sort_values('TopSpeed_km_per_h', ascending=False).head(20)

# Define a custom color palette
colors = sns.color_palette('husl', len(top_20_fastest['Brand'].unique()))

# Create the bar plot with the custom color palette
sns.barplot(data=top_20_fastest, x='Model', y='TopSpeed_km_per_h', hue='Brand', palette=colors)

plt.title('Top 20 Fastest Electric Cars')
plt.xlabel('Model')
plt.ylabel('Speed (km/h)')
plt.legend(title='Brand', loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatter plot
sns.scatterplot(data=df2, x='Seats', y='PriceEuro', color='blue', marker='o')

# Create the line plot
sns.lineplot(data=df2, x='Seats', y='PriceEuro', color='cyan')

# Set the plot title and axis labels
plt.title('Relationship between Seats and Price')
plt.xlabel('Number of Seats')
plt.ylabel('Price (Euro)')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatter plot
sns.scatterplot(data=df2, x='Efficiency_wh_per_km', y='PriceEuro', color='purple', marker='s')

# Create the line plot
sns.lineplot(data=df2, x='Efficiency_wh_per_km', y='PriceEuro', color='green')

# Set the plot title and axis labels
plt.title('Relationship between Efficiency and Price')
plt.xlabel('Efficiency (wh/km)')
plt.ylabel('Price (Euro)')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatter plot
sns.scatterplot(data=df2, x='Efficiency_wh_per_km', y='TopSpeed_km_per_h', color='blue', marker='o')

# Create the line plot
sns.lineplot(data=df2, x='Efficiency_wh_per_km', y='TopSpeed_km_per_h', color='red')

# Set the plot title and axis labels
plt.title('Efficiency and Top Speed')
plt.xlabel('Efficiency (wh/km)')
plt.ylabel('Top Speed (km/h)')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot
sns.set(style='ticks')

# Create the scatter plot
sns.scatterplot(data=df2, x='TopSpeed_km_per_h', y='PriceEuro', color='blue', marker='o')

# Add a line plot to connect the highest speed and price points
sns.lineplot(data=df2, x='TopSpeed_km_per_h', y='PriceEuro', color='red')

# Set the plot title and axis labels
plt.title('Top Speed and Price')
plt.xlabel('Top Speed (km/h)')
plt.ylabel('Price (Euro)')

# Show the plot
plt.show()

# %%
df_old = df2

# %%
unique_values = df2['RapidCharge'].unique()

# Print the unique values
print(unique_values)
# Out:
# ['Rapid charging possible']

# %%
unique_values = df2['PowerTrain'].unique()

# Print the unique values
print(unique_values)
# Out:
# ['All Wheel Drive' 'Rear Wheel Drive' 'Front Wheel Drive']

# %%
mapping = {'Rear Wheel Drive' : 0 , 'Front Wheel Drive' : 1, 'All Wheel Drive' : 2}
df2['PowerTrain'] = df2['PowerTrain'].map(mapping)

# %%
unique_values = df2['BodyStyle'].unique()

# Print the unique values
print(unique_values)
# Out:
# ['Sedan' 'Hatchback' 'Liftback' 'SUV' 'Pickup' 'MPV' 'Cabrio' 'SPV'
#  'Station']

# %%
mapping = {'Sedan' : 0 , 'Hatchback' : 1, 'Liftback' : 2, 'SUV': 3, 'Pickup': 4 , 'MPV':5, 'Cabrio':6 , 'SPV':7, 'Station':8}
df2['BodyStyle'] = df2['BodyStyle'].map(mapping)

# %%
df2.head(1)
# Out:
#     Brand                          Model  Accel_sec  TopSpeed_km_per_h  \
# 0  Tesla   Model 3 Long Range Dual Motor        4.6                233
#
#    Range_km  Efficiency_wh_per_km  FastCharge_km_per_h  \
# 0       450                   161                  940
#
#                RapidCharge  PowerTrain    PlugType  BodyStyle Segment  Seats  \
# 0  Rapid charging possible           2  Type 2 CCS          0       D      5
#
#    PriceEuro
# 0      55480
# No charts were generated by quickchart

# %%
df2 = df2.drop('Model',axis=1)

# %%
df2 = df2.drop('RapidCharge',axis=1)

# %%
df2 = df2.drop('Segment',axis=1)

# %%
df2 = df2.drop('PlugType',axis=1)

# %%
df2 = df2.drop('Brand',axis=1)

# %%
df2.head(2)
# Out:
#    Accel_sec  TopSpeed_km_per_h  Range_km  Efficiency_wh_per_km  \
# 0        4.6                233       450                   161
# 1       10.0                160       270                   167
#
#    FastCharge_km_per_h  PowerTrain  BodyStyle  Seats  PriceEuro
# 0                  940           2          0      5      55480
# 1                  250           0          1      5      30000

# %%
from sklearn import preprocessing
scaler = preprocessing.RobustScaler()
robust_df = scaler.fit_transform(df2)
df3 = pd.DataFrame(robust_df, columns =df2.columns)

# %%
df3.shape
# Out:
# (98, 9)

# %%
from sklearn.decomposition import PCA
import pandas as pd

n_components = 7  # Replace with the desired number of components
pca = PCA(n_components)

# Apply PCA to the data in one step
X_pca = pca.fit_transform(df3)

# Create a new DataFrame with the PCA-transformed data
df4 = pd.DataFrame(data=X_pca, columns=[f'PC{i}' for i in range(1, n_components + 1)])

df4.head(2)
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0  1.388088 -1.436838 -1.530647 -0.291693  0.395170 -0.346903 -0.465491
# 1 -1.894228 -0.527815 -0.154070  0.443409 -0.281675  0.478496  0.172742

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(df4)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from sklearn.cluster import KMeans

n_clusters = 3  # Replace with the desired number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=0)

# Fit the data to the KMeans model and predict the cluster labels
labels = kmeans.fit_predict(df4)

# Add the cluster labels to the DataFrame
df4['Cluster'] = labels

# Display the DataFrame with cluster assignments
print(df4)
# Out:
#          PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   1.388088 -1.436838 -1.530647 -0.291693  0.395170 -0.346903 -0.465491
# 1  -1.894228 -0.527815 -0.154070  0.443409 -0.281675  0.478496  0.172742
# 2   0.894897 -0.296647 -0.592903 -0.360242  0.410476 -0.406863 -0.371894
# 3   0.128103  0.224753  0.178142  0.892473 -0.944090  0.385962 -0.120284
# 4  -2.269866 -0.943807  0.774053  0.054029 -0.508489  0.252921 -0.154193
# ..       ...       ...       ...       ...       ...       ...       ...
# 93 -0.623492 -0.304529 -0.313902 -0.258215 -0.293027  0.085914  0.314754
# 94  1.907828  0.884387  0.684306 -0.972596 -0.737165  0.245985  0.013358
# 95  0.248251 -0.312485 -0.380360 -0.960244  0.174596 -0.106693 -0.062100
# 96  0.956093  0.079461 -0.161055 -1.141547 -0.501565 -0.106270  0.386400
# 97  0.811148  0.919749  0.195197 -0.658102 -0.297990 -0.422495  0.371115
#
#     Cluster
# 0         0
# 1         1
# 2         0
# 3         1
# 4         1
# ..      ...
# 93        1
# 94        0
# 95        0
# 96        0
# 97        0
#
# [98 rows x 8 columns]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Get the cluster centers in the PCA space
cluster_centers_pca = kmeans.cluster_centers_

# Create a scatter plot of the data points in the PCA space
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5, label='Data Points')

# Create a scatter plot of the cluster centers in the PCA space
plt.scatter(cluster_centers_pca[:, 0], cluster_centers_pca[:, 1], c='red', marker='x', label='Cluster Centers')

# Set the x-axis label, y-axis label, and plot title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Cluster Centers in PCA Space')

# Add a legend to the plot
plt.legend()

# Show the plot
plt.show()

# %%
df_old['Cluster'] = labels
df_old.head(1)
# Out:
#     Brand                          Model  Accel_sec  TopSpeed_km_per_h  \
# 0  Tesla   Model 3 Long Range Dual Motor        4.6                233
#
#    Range_km  Efficiency_wh_per_km  FastCharge_km_per_h  \
# 0       450                   161                  940
#
#                RapidCharge  PowerTrain    PlugType  BodyStyle Segment  Seats  \
# 0  Rapid charging possible           2  Type 2 CCS          0       D      5
#
#    PriceEuro  Cluster
# 0      55480        0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatter plot
sns.scatterplot(data=df_old, x='PriceEuro', y='Cluster', color='green', marker='o')

# Set the plot title and axis labels
plt.title('Cluster and Price')
plt.xlabel('Price (Euro)')
plt.ylabel('Cluster')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.shape
# Out:
# (103, 14)

# %%
import pandas as pd

df = pd.read_csv("/content/Electric_Vehicle_Data.csv")
df_copy = df
df.head()
# Out:
#    Unnamed: 0  Age       City Profession Marital Status Education  \
# 0           0   30      Nabha       None         Single  Graduate
# 1           1   27       Pune       None         Single  Graduate
# 2           2   32  Kashipur        None         Single  Graduate
# 3           3   55       Pune   Business         Single  Graduate
# 4           4   26     Satara       None         Single  Graduate
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Unnamed: 0                                                            1000 non-null   int64
#  1   Age                                                                   1000 non-null   int64
#  2   City                                                                  1000 non-null   object
#  3   Profession                                                            1000 non-null   object
#  4   Marital Status                                                        1000 non-null   object
#  5   Education                                                             1000 non-null   object
#  6   No. of Family members                                                 1000 non-null   int64
#  7   Annual Income                                                         1000 non-null   float64
#  8   Would you prefer replacing all your vehicles to Electronic vehicles?  1000 non-null   object
#  9   If Yes/Maybe what type of  EV would you prefer?                       1000 non-null   object
#  10  Do you think Electronic Vehicles are economical?                      1000 non-null   object
#  11  Which brand of vehicle do you currently own?                          1000 non-null   object
#  12  How much money could you spend on an Electronic vehicle?              1000 non-null   object
#  13  Preference for wheels in EV                                           1000 non-null   int64
#  14  Do you think Electronic vehicles will replace fuel cars in India?     1000 non-null   object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 117.3+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0          Age  No. of Family members  Annual Income  \
# count  1000.000000  1000.000000            1000.000000   1.000000e+03
# mean    499.500000    31.800000               4.118000   2.258342e+06
# std     288.819436    11.294847               1.469774   9.993558e+05
# min       0.000000    15.000000               0.000000  -3.761509e+05
# 25%     249.750000    26.000000               4.000000   1.782116e+06
# 50%     499.500000    29.000000               4.000000   2.329246e+06
# 75%     749.250000    31.000000               5.000000   2.753170e+06
# max     999.000000   118.000000               8.000000   1.282128e+07
#
#        Preference for wheels in EV
# count                  1000.000000
# mean                      3.349000
# std                       0.887686
# min                       2.000000
# 25%                       2.000000
# 50%                       4.000000
# 75%                       4.000000
# max                       4.000000

# %%
df.describe(include="object")
# Out:
#         City Profession Marital Status Education  \
# count   1000       1000           1000      1000
# unique    35          4              2         2
# top     Pune       None         Single  Graduate
# freq     570        460            638       693
#
#        Would you prefer replacing all your vehicles to Electronic vehicles?  \
# count                                                1000
# unique                                                  3
# top                                                   Yes
# freq                                                  663
#
#        If Yes/Maybe what type of  EV would you prefer?  \
# count                                             1000
# unique                                               5
# top                                                SUV
# freq                                               467
#
#        Do you think Electronic Vehicles are economical?  \
# count                                              1000
# unique                                                3
# top                                                 Yes
# freq                                                768
#
#        Which brand of vehicle do you currently own?  \
# count                                          1000
# unique                                           16
# top                                            Tata
# freq                                            186
#
#        How much money could you spend on an Electronic vehicle?  \
# count                                                1000
# unique                                                  8
# top                                             <15 lakhs
# freq                                                  483
#
#        Do you think Electronic vehicles will replace fuel cars in India?
# count                                                1000
# unique                                                  4
# top                                     Yes, in <10 years
# freq                                                  419

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'City', 'Profession', 'Marital Status',
#        'Education', 'No. of Family members', 'Annual Income',
#        'Would you prefer replacing all your vehicles to Electronic vehicles?',
#        'If Yes/Maybe what type of  EV would you prefer?',
#        'Do you think Electronic Vehicles are economical?',
#        'Which brand of vehicle do you currently own?',
#        'How much money could you spend on an Electronic vehicle?',
#        'Preference for wheels in EV',
#        'Do you think Electronic vehicles will replace fuel cars in India?'],
#       dtype='object')

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#    Age       City Profession Marital Status Education  No. of Family members  \
# 0   30      Nabha       None         Single  Graduate                      5
# 1   27       Pune       None         Single  Graduate                      4
# 2   32  Kashipur        None         Single  Graduate                      4
# 3   55       Pune   Business         Single  Graduate                      3
# 4   26     Satara       None         Single  Graduate                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4864147235571151213 = autoviz.get_registered_df('df_4864147235571151213')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4864147235571151213, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2230587769033427623 = autoviz.get_registered_df('df_2230587769033427623')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2230587769033427623, *['No. of Family members'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7533422822336262010 = autoviz.get_registered_df('df_7533422822336262010')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7533422822336262010, *['Annual Income'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6055142505107691279 = autoviz.get_registered_df('df_6055142505107691279')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6055142505107691279, *['Preference for wheels in EV'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2150713497271434881 = autoviz.get_registered_df('df_2150713497271434881')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2150713497271434881, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2850173608478880216 = autoviz.get_registered_df('df_2850173608478880216')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2850173608478880216, *['No. of Family members'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_938600438933777446 = autoviz.get_registered_df('df_938600438933777446')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_938600438933777446, *['Annual Income'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_840246810801816252 = autoviz.get_registered_df('df_840246810801816252')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_840246810801816252, *['Preference for wheels in EV'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8243261374791077894 = autoviz.get_registered_df('df_8243261374791077894')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_8243261374791077894, *['City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5785309281096568899 = autoviz.get_registered_df('df_5785309281096568899')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_5785309281096568899, *['Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7324712451370185010 = autoviz.get_registered_df('df_7324712451370185010')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_7324712451370185010, *['Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_682377456413345270 = autoviz.get_registered_df('df_682377456413345270')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_682377456413345270, *['If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6415531815383078135 = autoviz.get_registered_df('df_6415531815383078135')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_6415531815383078135, *[[['Age', 'No. of Family members'], ['No. of Family members', 'Annual Income'], ['Annual Income', 'Preference for wheels in EV']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6177382678810529438 = autoviz.get_registered_df('df_6177382678810529438')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_6177382678810529438, *['City', 'Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2279354677694500137 = autoviz.get_registered_df('df_2279354677694500137')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_2279354677694500137, *['Profession', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4076429740218281124 = autoviz.get_registered_df('df_4076429740218281124')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_4076429740218281124, *['Would you prefer replacing all your vehicles to Electronic vehicles?', 'If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2765430477210849016 = autoviz.get_registered_df('df_2765430477210849016')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_2765430477210849016, *['If Yes/Maybe what type of  EV would you prefer?', 'Do you think Electronic Vehicles are economical?'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3593855171721207599 = autoviz.get_registered_df('df_3593855171721207599')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_3593855171721207599, *['Age', 'City'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_742710569663107864 = autoviz.get_registered_df('df_742710569663107864')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_742710569663107864, *['Age', 'Profession'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_540354739904648646 = autoviz.get_registered_df('df_540354739904648646')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_540354739904648646, *['Age', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7648343218384541635 = autoviz.get_registered_df('df_7648343218384541635')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_7648343218384541635, *['Age', 'If Yes/Maybe what type of  EV would you prefer?'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7551655227458950260 = autoviz.get_registered_df('df_7551655227458950260')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7551655227458950260, *['Preference for wheels in EV', 'Age', 'City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6436757962595334715 = autoviz.get_registered_df('df_6436757962595334715')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_6436757962595334715, *['Preference for wheels in EV', 'Age', 'Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2581815224848411691 = autoviz.get_registered_df('df_2581815224848411691')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2581815224848411691, *['Preference for wheels in EV', 'Age', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5611492491610238945 = autoviz.get_registered_df('df_5611492491610238945')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5611492491610238945, *['Preference for wheels in EV', 'Age', 'If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart

# %%
df.isnull().sum()
# Out:
# Age                                                                     0
# City                                                                    0
# Profession                                                              0
# Marital Status                                                          0
# Education                                                               0
# No. of Family members                                                   0
# Annual Income                                                           0
# Would you prefer replacing all your vehicles to Electronic vehicles?    0
# If Yes/Maybe what type of  EV would you prefer?                         0
# Do you think Electronic Vehicles are economical?                        0
# Which brand of vehicle do you currently own?                            0
# How much money could you spend on an Electronic vehicle?                0
# Preference for wheels in EV                                             0
# Do you think Electronic vehicles will replace fuel cars in India?       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))  # Set the figure size to 8x6 inches
sns.distplot(df["Age"], color="purple", hist_kws={"alpha": 0.6, "linewidth": 1.5})  # Plot the distribution of the "Age" column

plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Density")

plt.show()  # Show the plot

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))  # Set the figure size to 6x6 inches
df["Profession"].value_counts().plot(kind="pie", autopct="%0.1f%%")  # Plot the pie chart

plt.title("Distribution of Professions")
plt.ylabel("")  # Remove the y-axis label

plt.show()  # Show the plot

# %%
df["Marital Status"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='Marital Status'>

# %%
df["City"].unique()
# Out:
# array(['Nabha', 'Pune', 'Kashipur ', 'Satara', 'Noida', 'Delhi', 'Mumbai',
#        'pune', 'solapur', 'Haldwani ', 'Nellore ', 'Pune ', 'Haldwani',
#        'Banglore ', 'Faridabad ', 'Nagpur', 'Chandrapur ', 'Chennai',
#        'Gurugram ', 'Nashik', 'Bengaluru', 'Mumbai ', 'Hakdwani',
#        'Patiyala', 'pUNE', 'Ahmedabad', 'Karnal', 'Rewari', 'New Delhi',
#        'Serampore', 'Jhansi', 'New Delhi ', 'Jalandhar', 'Delhi ',
#        'nashik'], dtype=object)

# %%
df["City"] = df["City"].replace({"Pune ": "Pune", "pUNE": "Pune", "pune": "Pune", "Pune": "Pune"})
df["City"] = df["City"].replace({"Banglore ": "Bengaluru"})
df["City"] = df["City"].replace({"Hakdwani": "Haldwani", "Haldwani ": "Haldwani"})
df["City"] = df["City"].replace({"New Delhi ": "Delhi", "Delhi ": "Delhi"})
df["City"] = df["City"].replace({"nashik": "Nashik"})
df["City"] = df["City"].replace({"Mumbai ": "Mumbai"})

# %%
df["City"].unique()
# Out:
# array(['Nabha', 'Pune', 'Kashipur ', 'Satara', 'Noida', 'Delhi', 'Mumbai',
#        'solapur', 'Haldwani', 'Nellore ', 'Bengaluru', 'Faridabad ',
#        'Nagpur', 'Chandrapur ', 'Chennai', 'Gurugram ', 'Nashik',
#        'Patiyala', 'Ahmedabad', 'Karnal', 'Rewari', 'New Delhi',
#        'Serampore', 'Jhansi', 'Jalandhar'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="City", data=df, order=df["City"].value_counts().iloc[:5].index)

plt.title("Top 5 Cities")
plt.xlabel("City")
plt.ylabel("Count")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))  # Set the figure size to 6x6 inches
df["No. of Family members"].value_counts().plot(kind="bar", color="blue")  # Plot the bar plot

plt.title("Number of Family Members")
plt.xlabel("Number of Family Members")
plt.ylabel("Count")

plt.show()  # Show the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))  # Set the figure size to 6x6 inches
sns.histplot(df["Annual Income"], color="purple")  # Plot the histogram with a different color

plt.title("Distribution of Annual Income")
plt.xlabel("Annual Income")
plt.ylabel("Count")

plt.show()  # Show the plot

# %%
import matplotlib.pyplot as plt

df["Education"].value_counts().plot(kind="bar", color="skyblue")

plt.title("Education Distribution")
plt.xlabel("Education")
plt.ylabel("Count")

plt.show()

# %%
import matplotlib.pyplot as plt

df["Do you think Electronic Vehicles are economical?"].value_counts().plot(kind="bar", color="skyblue")

plt.title("Perception of Electric Vehicles' Economy")
plt.xlabel("Response")
plt.ylabel("Count")

plt.show()

# %%
import matplotlib.pyplot as plt

df["Preference for wheels in EV"].value_counts().plot(kind="bar", color="skyblue")

plt.title("Preference for Wheels in EV")
plt.xlabel("Preference")
plt.ylabel("Count")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))  # Set the figure size to 8x8 inches
df["How much money could you spend on an Electronic vehicle?"].value_counts().plot(kind="bar", color="skyblue")

plt.title("Spending Capacity on an Electronic Vehicle")
plt.xlabel("Spending Range")
plt.ylabel("Count")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 7))  # Set the figure size to 7x7 inches
df["Which brand of vehicle do you currently own?"].value_counts().plot(kind="bar", color="skyblue")

plt.title("Current Vehicle Ownership by Brand")
plt.xlabel("Vehicle Brand")
plt.ylabel("Count")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 7))  # Set the figure size to 18x7 inches
sns.countplot(x="Age", data=df, hue="Education")

plt.title("Count of Education by Age")
plt.xlabel("Age")
plt.ylabel("Count")

plt.show()

# %%
sns.countplot(x="Education",data=df,hue="Do you think Electronic Vehicles are economical?")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="No. of Family members",data=df,hue="Do you think Electronic Vehicles are economical?")
# Out:
# <Axes: xlabel='No. of Family members', ylabel='count'>

# %%
plt.figure(figsize=(13,6))
sns.countplot(x="No. of Family members",data=df,hue="Preference for wheels in EV")
# Out:
# <Axes: xlabel='No. of Family members', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Which brand of vehicle do you currently own?",data=df,hue="Profession")
# Out:
# <Axes: xlabel='Which brand of vehicle do you currently own?', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))  # Set the figure size to 10x8 inches
cmap = sns.color_palette("coolwarm", as_cmap=True)  # Define a custom color map

sns.heatmap(df.corr(), annot=True, cmap=cmap)

plt.title("Correlation Matrix")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
def label_encoder(data,column):
    label_encoder=LabelEncoder()
    return label_encoder.fit_transform(data[column].astype(str))

# %%
df.head()
# Out:
#    Age       City Profession Marital Status Education  No. of Family members  \
# 0   30      Nabha       None         Single  Graduate                      5
# 1   27       Pune       None         Single  Graduate                      4
# 2   32  Kashipur        None         Single  Graduate                      4
# 3   55       Pune   Business         Single  Graduate                      3
# 4   26     Satara       None         Single  Graduate                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7743066329170335805 = autoviz.get_registered_df('df_7743066329170335805')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7743066329170335805, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2792361721730917313 = autoviz.get_registered_df('df_2792361721730917313')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2792361721730917313, *['No. of Family members'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2849944887812728187 = autoviz.get_registered_df('df_2849944887812728187')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2849944887812728187, *['Annual Income'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1751105985747953382 = autoviz.get_registered_df('df_1751105985747953382')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1751105985747953382, *['Preference for wheels in EV'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3302158376246163722 = autoviz.get_registered_df('df_3302158376246163722')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3302158376246163722, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2110697301407449593 = autoviz.get_registered_df('df_2110697301407449593')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2110697301407449593, *['No. of Family members'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7369557203659342015 = autoviz.get_registered_df('df_7369557203659342015')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_7369557203659342015, *['Annual Income'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_124887281472126578 = autoviz.get_registered_df('df_124887281472126578')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_124887281472126578, *['Preference for wheels in EV'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4787006909530161788 = autoviz.get_registered_df('df_4787006909530161788')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_4787006909530161788, *['City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5941555065757351485 = autoviz.get_registered_df('df_5941555065757351485')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_5941555065757351485, *['Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_555447731689708319 = autoviz.get_registered_df('df_555447731689708319')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_555447731689708319, *['Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8773994095614561259 = autoviz.get_registered_df('df_8773994095614561259')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_8773994095614561259, *['If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6460540243917003025 = autoviz.get_registered_df('df_6460540243917003025')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_6460540243917003025, *[[['Age', 'No. of Family members'], ['No. of Family members', 'Annual Income'], ['Annual Income', 'Preference for wheels in EV']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5993199229327818973 = autoviz.get_registered_df('df_5993199229327818973')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_5993199229327818973, *['City', 'Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6213423459692981630 = autoviz.get_registered_df('df_6213423459692981630')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_6213423459692981630, *['Profession', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6825310006776671858 = autoviz.get_registered_df('df_6825310006776671858')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_6825310006776671858, *['Would you prefer replacing all your vehicles to Electronic vehicles?', 'If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5436755768772872277 = autoviz.get_registered_df('df_5436755768772872277')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_5436755768772872277, *['If Yes/Maybe what type of  EV would you prefer?', 'Do you think Electronic Vehicles are economical?'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6940321869740079492 = autoviz.get_registered_df('df_6940321869740079492')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_6940321869740079492, *['Age', 'City'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8564304599783882390 = autoviz.get_registered_df('df_8564304599783882390')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_8564304599783882390, *['Age', 'Profession'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5324272080630253689 = autoviz.get_registered_df('df_5324272080630253689')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_5324272080630253689, *['Age', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5190723387496717843 = autoviz.get_registered_df('df_5190723387496717843')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_5190723387496717843, *['Age', 'If Yes/Maybe what type of  EV would you prefer?'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8681863608348429159 = autoviz.get_registered_df('df_8681863608348429159')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8681863608348429159, *['Preference for wheels in EV', 'Age', 'City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7590023088867183823 = autoviz.get_registered_df('df_7590023088867183823')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7590023088867183823, *['Preference for wheels in EV', 'Age', 'Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4430960272556606274 = autoviz.get_registered_df('df_4430960272556606274')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_4430960272556606274, *['Preference for wheels in EV', 'Age', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2810526005906125254 = autoviz.get_registered_df('df_2810526005906125254')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2810526005906125254, *['Preference for wheels in EV', 'Age', 'If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart

# %%
df['City']= label_encoder(df,'City')
df['Profession']= label_encoder(df,'Profession')
df['Marital Status']= label_encoder(df,'Marital Status')
df['Education']= label_encoder(df,'Education')

# %%
df.head()
# Out:
#    Age  City  Profession  Marital Status  Education  No. of Family members  \
# 0   30    13           1               1          0                      5
# 1   27    20           1               1          0                      4
# 2   32    11           1               1          0                      4
# 3   55    20           0               1          0                      3
# 4   26    22           1               1          0                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years

# %%
df['Would you prefer replacing all your vehicles to Electronic vehicles?']= label_encoder(df,'Would you prefer replacing all your vehicles to Electronic vehicles?')
df['If Yes/Maybe what type of  EV would you prefer?']= label_encoder(df,'If Yes/Maybe what type of  EV would you prefer?')
df['Do you think Electronic Vehicles are economical?']= label_encoder(df,'Do you think Electronic Vehicles are economical?')
df['Which brand of vehicle do you currently own?']= label_encoder(df,'Which brand of vehicle do you currently own?')
df['Do you think Electronic vehicles will replace fuel cars in India?']= label_encoder(df,'Do you think Electronic vehicles will replace fuel cars in India?')
df['How much money could you spend on an Electronic vehicle?']= label_encoder(df,'How much money could you spend on an Electronic vehicle?')

# %%
df.head()
# Out:
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3552163138768867494, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3552163138768867494, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3552163138768867494, *['City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3552163138768867494, *['Profession'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3552163138768867494, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3552163138768867494, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3552163138768867494, *['City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3552163138768867494, *['Profession'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_3552163138768867494, *[[['index', 'Age'], ['Age', 'City'], ['City', 'Profession'], ['Profession', 'No. of Family members']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3552163138768867494, *['index', 'Age', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3552163138768867494, *['index', 'City', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3552163138768867494, *['index', 'Profession', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3552163138768867494 = autoviz.get_registered_df('df_3552163138768867494')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3552163138768867494, *['index', 'No. of Family members', None], **{})
# chart
#    Age  City  Profession  Marital Status  Education  No. of Family members  \
# 0   30    13           1               1          0                      5
# 1   27    20           1               1          0                      4
# 2   32    11           1               1          0                      4
# 3   55    20           0               1          0                      3
# 4   26    22           1               1          0                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#    Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  2
#
#    If Yes/Maybe what type of  EV would you prefer?  \
# 0                                                3
# 1                                                3
# 2                                                1
# 3                                                1
# 4                                                4
#
#    Do you think Electronic Vehicles are economical?  \
# 0                                                 2
# 1                                                 2
# 2                                                 2
# 3                                                 1
# 4                                                 2
#
#    Which brand of vehicle do you currently own?  \
# 0                                            10
# 1                                             9
# 2                                            11
# 3                                            10
# 4                                             2
#
#    How much money could you spend on an Electronic vehicle?  \
# 0                                                  6
# 1                                                  4
# 2                                                  4
# 3                                                  6
# 4                                                  4
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#    Do you think Electronic vehicles will replace fuel cars in India?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    Preference for replacing all vehicles with EV
# 0                                              0
# 1                                              2
# 2                                              2
# 3                                              0
# 4                                              2

# %%
#k-mean model

# %%
df.head()
# Out:
#    Age  City  Profession  Marital Status  Education  No. of Family members  \
# 0   30    13           1               1          0                      5
# 1   27    20           1               1          0                      4
# 2   32    11           1               1          0                      4
# 3   55    20           0               1          0                      3
# 4   26    22           1               1          0                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#    Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  2
#
#    If Yes/Maybe what type of  EV would you prefer?  \
# 0                                                3
# 1                                                3
# 2                                                1
# 3                                                1
# 4                                                4
#
#    Do you think Electronic Vehicles are economical?  \
# 0                                                 2
# 1                                                 2
# 2                                                 2
# 3                                                 1
# 4                                                 2
#
#    Which brand of vehicle do you currently own?  \
# 0                                            10
# 1                                             9
# 2                                            11
# 3                                            10
# 4                                             2
#
#    How much money could you spend on an Electronic vehicle?  \
# 0                                                  6
# 1                                                  4
# 2                                                  4
# 3                                                  6
# 4                                                  4
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#    Do you think Electronic vehicles will replace fuel cars in India?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    Preference for replacing all vehicles with EV
# 0                                              0
# 1                                              2
# 2                                              2
# 3                                              0
# 4                                              2

# %%
y=df["City"]
x=df.drop(["City"],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif['VIF']=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    return(vif)

# %%
x=df.iloc[:,:-1]

# %%
vif(x)
# Out:
#                                             variables        VIF
# 0                                                 Age   8.042569
# 1                                                City   7.942111
# 2                                          Profession   2.907977
# 3                                      Marital Status   2.712687
# 4                                           Education   1.441175
# 5                               No. of Family members   8.483919
# 6                                       Annual Income   5.764886
# 7   Would you prefer replacing all your vehicles t...   4.126685
# 8     If Yes/Maybe what type of  EV would you prefer?   7.199396
# 9    Do you think Electronic Vehicles are economical?   6.355330
# 10       Which brand of vehicle do you currently own?   7.622565
# 11  How much money could you spend on an Electroni...  13.566270
# 12                        Preference for wheels in EV  12.782161
# 13  Do you think Electronic vehicles will replace ...   4.800050
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4986319754886773625 = autoviz.get_registered_df('df_4986319754886773625')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4986319754886773625, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6976083794796877987 = autoviz.get_registered_df('df_6976083794796877987')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6976083794796877987, *['VIF'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6079949021753885609 = autoviz.get_registered_df('df_6079949021753885609')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6079949021753885609, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7724368399680036103 = autoviz.get_registered_df('df_7724368399680036103')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_7724368399680036103, *['VIF'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_368788548641039823 = autoviz.get_registered_df('df_368788548641039823')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_368788548641039823, *[[['index', 'VIF']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4136998153540132551 = autoviz.get_registered_df('df_4136998153540132551')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_4136998153540132551, *['index', 'VIF', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_808567632684257512 = autoviz.get_registered_df('df_808567632684257512')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_808567632684257512, *['index', 'count()', None], **{})
# chart

# %%
#pca implimentation

# %%
from sklearn.decomposition import PCA

# Perform PCA
pca = PCA(n_components=4)
pca_data = pca.fit_transform(df)
df2 = pd.DataFrame(pca_data, columns=['PC1', 'PC2','PC3','PC4'])
df2.head()
# Out:
#             PC1        PC2       PC3       PC4
# 0 -1.064466e+06  -1.950017  3.470951 -1.665758
# 1 -4.138014e+05  -4.853762 -3.483520 -0.704910
# 2  6.898083e+05   0.279855  5.676591 -2.541031
# 3  5.740379e+05  23.299583 -3.282237 -1.775232
# 4  3.804088e+05  -5.722283 -5.534838  6.245799

# %%
#clustering using  elbow methid

# %%
from sklearn.cluster import KMeans

# Determine the number of clusters using the Elbow method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# Plot the Elbow curve
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.grid()
plt.show()

# %%
# Perform K-means clustering algo. with the optimal number of clusters
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Add the cluster labels to the dataset
df['Cluster'] = kmeans.labels_

# Define a custom color and size
color_map = 'cool'  # Change the color map as desired
marker_size = 50  # Change the marker size as desired

# Visualize the clusters
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=df['Cluster'], cmap=color_map, s=marker_size)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('EV Market Segmentation - Cluster Analysis')
plt.colorbar(label='Cluster')

plt.show()

# %%
# future prediction

# %%
kmeans_predict=KMeans(n_clusters=4,random_state=123)
clusters=kmeans_predict.fit_predict(df)
df_copy["Clusters"]=clusters

# %%
df_copy.head()
# Out:
#    Unnamed: 0  Age       City Profession Marital Status Education  \
# 0           0   30      Nabha       None         Single  Graduate
# 1           1   27       Pune       None         Single  Graduate
# 2           2   32  Kashipur        None         Single  Graduate
# 3           3   55       Pune   Business         Single  Graduate
# 4           4   26     Satara       None         Single  Graduate
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6949214092701993935 = autoviz.get_registered_df('df_6949214092701993935')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6949214092701993935, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7221363682744742950 = autoviz.get_registered_df('df_7221363682744742950')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7221363682744742950, *['Unnamed: 0'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3466647936826625501 = autoviz.get_registered_df('df_3466647936826625501')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3466647936826625501, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8132607974815873392 = autoviz.get_registered_df('df_8132607974815873392')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8132607974815873392, *['No. of Family members'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8493724761962870841 = autoviz.get_registered_df('df_8493724761962870841')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8493724761962870841, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4439361172274750848 = autoviz.get_registered_df('df_4439361172274750848')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_4439361172274750848, *['Unnamed: 0'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5633569681294857162 = autoviz.get_registered_df('df_5633569681294857162')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_5633569681294857162, *['Age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8912260770256914511 = autoviz.get_registered_df('df_8912260770256914511')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8912260770256914511, *['No. of Family members'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6243422813458860866 = autoviz.get_registered_df('df_6243422813458860866')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_6243422813458860866, *['City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_684537626763625301 = autoviz.get_registered_df('df_684537626763625301')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_684537626763625301, *['Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_646862726258815436 = autoviz.get_registered_df('df_646862726258815436')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_646862726258815436, *['Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7137068285078228551 = autoviz.get_registered_df('df_7137068285078228551')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_7137068285078228551, *['If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4381539256479828918 = autoviz.get_registered_df('df_4381539256479828918')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_4381539256479828918, *[[['index', 'Unnamed: 0'], ['Unnamed: 0', 'Age'], ['Age', 'No. of Family members'], ['No. of Family members', 'Annual Income']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_282325414758409878 = autoviz.get_registered_df('df_282325414758409878')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_282325414758409878, *['City', 'Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2590065147273829156 = autoviz.get_registered_df('df_2590065147273829156')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_2590065147273829156, *['Profession', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1332837971250456786 = autoviz.get_registered_df('df_1332837971250456786')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_1332837971250456786, *['Would you prefer replacing all your vehicles to Electronic vehicles?', 'If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4986962061635936812 = autoviz.get_registered_df('df_4986962061635936812')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2), mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_4986962061635936812, *['If Yes/Maybe what type of  EV would you prefer?', 'Do you think Electronic Vehicles are economical?'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_460273206120218352 = autoviz.get_registered_df('df_460273206120218352')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_460273206120218352, *['index', 'City'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_536039182604262020 = autoviz.get_registered_df('df_536039182604262020')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_536039182604262020, *['index', 'Profession'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1624983578440985340 = autoviz.get_registered_df('df_1624983578440985340')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_1624983578440985340, *['index', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_898935031386860434 = autoviz.get_registered_df('df_898935031386860434')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_898935031386860434, *['index', 'If Yes/Maybe what type of  EV would you prefer?'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7382122516889912392 = autoviz.get_registered_df('df_7382122516889912392')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7382122516889912392, *['index', 'Age', 'City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7902705855494799350 = autoviz.get_registered_df('df_7902705855494799350')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7902705855494799350, *['index', 'Age', 'Profession'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6614359575144438924 = autoviz.get_registered_df('df_6614359575144438924')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_6614359575144438924, *['index', 'Age', 'Would you prefer replacing all your vehicles to Electronic vehicles?'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5364605453569831141 = autoviz.get_registered_df('df_5364605453569831141')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5364605453569831141, *['index', 'Age', 'If Yes/Maybe what type of  EV would you prefer?'], **{})
# chart

# %%
#Ev type preference of the people

# %%
df_copy["Clusters"].value_counts()
# Out:
# 1    434
# 0    366
# 3    193
# 2      7
# Name: Clusters, dtype: int64

# %%
Cluster_0=df_copy[df_copy.Clusters==0]
Cluster_1=df_copy[df_copy.Clusters==1]
Cluster_2=df_copy[df_copy.Clusters==2]
Cluster_3=df_copy[df_copy.Clusters==3]

# %%
#ev pref
 [Cluster_0["Preference for wheels in EV"].value_counts().head(),
Cluster_1["Preference for wheels in EV"].value_counts().head(),
Cluster_2["Preference for wheels in EV"].value_counts().head(),
Cluster_3["Preference for wheels in EV"].value_counts().head()]

# 4 wheeler are more preferred EV vehicle in the market
# Followed by 2 wheeler and 3 wheeler
# Out:
# [4    230
#  2    100
#  3     36
#  Name: Preference for wheels in EV, dtype: int64,
#  4    266
#  2    126
#  3     42
#  Name: Preference for wheels in EV, dtype: int64,
#  4    4
#  2    2
#  3    1
#  Name: Preference for wheels in EV, dtype: int64,
#  4    129
#  2     52
#  3     12
#  Name: Preference for wheels in EV, dtype: int64]

# %%
[Cluster_0['Which brand of vehicle do you currently own?'].value_counts().head(),
 Cluster_1['Which brand of vehicle do you currently own?'].value_counts().head(),
 Cluster_2['Which brand of vehicle do you currently own?'].value_counts().head(),
 Cluster_3['Which brand of vehicle do you currently own?'].value_counts().head()]
# Out:
# [Tata       68
#  Hyundai    62
#  KIA        53
#  Honda      51
#  Nissan     47
#  Name: Which brand of vehicle do you currently own?, dtype: int64,
#  Tata       79
#  Hyundai    71
#  Honda      66
#  KIA        62
#  Nissan     53
#  Name: Which brand of vehicle do you currently own?, dtype: int64,
#  Tata       3
#  KIA        1
#  MG         1
#  Honda      1
#  Hyundai    1
#  Name: Which brand of vehicle do you currently own?, dtype: int64,
#  Tata       36
#  Hyundai    31
#  KIA        28
#  Honda      26
#  Nissan     22
#  Name: Which brand of vehicle do you currently own?, dtype: int64]

# %%
print(Cluster_0['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
print(Cluster_1['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
print(Cluster_2['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())
print(Cluster_3['If Yes/Maybe what type of  EV would you prefer?'].value_counts().head())

#Suv and Sedan are the most preferred EV in all the cluster
# Out:
# SUV          175
# Sedan         84
# Hatchback     54
# Liftback      43
# Cabrio        10
# Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64
# SUV          193
# Sedan        116
# Hatchback     63
# Liftback      46
# Cabrio        16
# Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64
# SUV          3
# Sedan        2
# Hatchback    1
# Liftback     1
# Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64
# SUV          96
# Sedan        38
# Liftback     30
# Hatchback    26
# Cabrio        3
# Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64

# %%
[Cluster_0["How much money could you spend on an Electronic vehicle?"].value_counts().head(),
Cluster_1["How much money could you spend on an Electronic vehicle?"].value_counts().head(),
Cluster_2["How much money could you spend on an Electronic vehicle?"].value_counts().head(),
Cluster_3["How much money could you spend on an Electronic vehicle?"].value_counts().head()]
# Out:
# [<15 lakhs    159
#  <5 lakhs     106
#  <25 lakhs     69
#  >25 lakhs     14
#  700000         6
#  Name: How much money could you spend on an Electronic vehicle?, dtype: int64,
#  <15 lakhs    219
#  <5 lakhs     128
#  <25 lakhs     49
#  >25 lakhs     15
#  1200000        7
#  Name: How much money could you spend on an Electronic vehicle?, dtype: int64,
#  <15 lakhs    3
#  <5 lakhs     3
#  <25 lakhs    1
#  Name: How much money could you spend on an Electronic vehicle?, dtype: int64,
#  <15 lakhs    102
#  <5 lakhs      51
#  <25 lakhs     29
#  >25 lakhs      5
#  1200000        3
#  Name: How much money could you spend on an Electronic vehicle?, dtype: int64]

# %%
[Cluster_0["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),
Cluster_1["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),
Cluster_2["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head(),
Cluster_3["Would you prefer replacing all your vehicles to Electronic vehicles?"].value_counts().head()]
# Out:
# [Yes      235
#  Maybe     76
#  No        55
#  Name: Would you prefer replacing all your vehicles to Electronic vehicles?, dtype: int64,
#  Yes      287
#  Maybe     87
#  No        60
#  Name: Would you prefer replacing all your vehicles to Electronic vehicles?, dtype: int64,
#  Yes    7
#  Name: Would you prefer replacing all your vehicles to Electronic vehicles?, dtype: int64,
#  Yes      134
#  Maybe     38
#  No        21
#  Name: Would you prefer replacing all your vehicles to Electronic vehicles?, dtype: int64]

# %%
[Cluster_0["If Yes/Maybe what type of  EV would you prefer?"].value_counts().head(),
Cluster_1["If Yes/Maybe what type of  EV would you prefer?"].value_counts().head(),
Cluster_2["If Yes/Maybe what type of  EV would you prefer?"].value_counts().head(),
Cluster_3["If Yes/Maybe what type of  EV would you prefer?"].value_counts().head()]
# Out:
# [SUV          175
#  Sedan         84
#  Hatchback     54
#  Liftback      43
#  Cabrio        10
#  Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64,
#  SUV          193
#  Sedan        116
#  Hatchback     63
#  Liftback      46
#  Cabrio        16
#  Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64,
#  SUV          3
#  Sedan        2
#  Hatchback    1
#  Liftback     1
#  Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64,
#  SUV          96
#  Sedan        38
#  Liftback     30
#  Hatchback    26
#  Cabrio        3
#  Name: If Yes/Maybe what type of  EV would you prefer?, dtype: int64]

# %%
[Cluster_0["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head(),
Cluster_1["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head(),
Cluster_2["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head(),
Cluster_3["Do you think Electronic vehicles will replace fuel cars in India?"].value_counts().head()]
# Out:
# [Yes, in <10 years               155
#  Yes, in <20years                133
#  Yes, possibly after 20 years     53
#  I don't think so                 25
#  Name: Do you think Electronic vehicles will replace fuel cars in India?, dtype: int64,
#  Yes, in <10 years               186
#  Yes, in <20years                176
#  Yes, possibly after 20 years     55
#  I don't think so                 17
#  Name: Do you think Electronic vehicles will replace fuel cars in India?, dtype: int64,
#  Yes, in <10 years               4
#  Yes, possibly after 20 years    2
#  Yes, in <20years                1
#  Name: Do you think Electronic vehicles will replace fuel cars in India?, dtype: int64,
#  Yes, in <20years                77
#  Yes, in <10 years               74
#  Yes, possibly after 20 years    22
#  I don't think so                20
#  Name: Do you think Electronic vehicles will replace fuel cars in India?, dtype: int64]
